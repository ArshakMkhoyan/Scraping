# %%
import requests
from selenium import webdriver
from scrapy.http import TextResponse
import time
import pandas as pd

# %%
browser = webdriver.Chrome('/home/ml-05/Desktop/Scrapping/chromedriver') #selenium lets us to control chrome page, each time we need to run this for new url

# %%
browser.get('http://hosted.where2getit.com/dollargeneral/index.html')
time.sleep(15)
element = browser.find_element_by_xpath('//*[@id="add_div"]/span[3]/a')

page=browser.page_source
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
print(element)
element.exists()

# %%
page
# Out:
# '<html lang="en" class=" localstorage csspointerevents no-touchevents csscolumns csscolumns-width csscolumns-span csscolumns-fill csscolumns-gap csscolumns-rule csscolumns-rulecolor csscolumns-rulestyle csscolumns-rulewidth csscolumns-breakbefore csscolumns-breakafter csscolumns-breakinside cssanimations csspseudoanimations js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths"><head><style type="text/css" id="monetatecss">/*Blank CSS Append*/\n\n#nav_menu_container .main-sublevelmenu-left li a[id="1184"] {\n  color: red !important;\n}\n</style><style>.gm-style-pbc{transition:opaci
# ...

# %%
response = requests.post('http://hosted.where2getit.com/dollargeneral/rest/locatorsearch?like=0.8023634240726956', data="""{
    "request": {
        "appkey": "9E9DE426-8151-11E4-AEAC-765055A65BB0",
        "formdata": {
            "geoip": false,
            "dataview": "store_default",
            "geolocs": {
                "geoloc": [
                    {
                        "addressline": "85001",
                        "country": "",
                        "latitude": "",
                        "longitude": ""
                    }
                ]
            },
            "searchradius": "10|20|50|100",
            "where": {
                "nci": {
                    "eq": ""
                },
                "and": {
                    "PROPANE": {
                        "eq": ""
                    },
                    "REDBOX": {
                        "eq": ""
                    },
                    "RUGDR": {
                        "eq": ""
                    },
                    "MULTICULTURAL_HAIR": {
                        "eq": ""
                    },
                    "TYPE_ID": {
                        "eq": ""
                    },
                    "DGGOCHECKOUT": {
                        "eq": ""
                    },
                    "FEDEX": {
                        "eq": ""
                    },
                    "DGGOCART": {
                        "eq": ""
                    },
                    "DGPICKUP": {
                        "eq": ""
                    },
                    "NCI": {
                        "eq": ""
                    }
                }
            },
            "false": "0"
        }
    }
}""")

# %%
response.text
# Out:
# '{ "response": {"attributes":{"address":"","centerpoint":"-112.0739,33.454","province":"","state":"AZ","city":"PHOENIX","country":"US","postalcode":"85001","radiusuom":"mile","radius":"10"},"activeobject":"","collectionname":"poi","collectioncount":10,"collection":[{"dg_go_register":null,"district":null,"dg_go":"1","city":"Phoenix","ship_state_code":null,"store_hours":null,"name":"Dollar General # 19421","longitude":"-112.0556","closing_time_mon":"21:00","address1":"1219 E Van Buren St","closing_time_thu":"21:00","urban":"1","ship_address4":null,"opening_time_sun":"07:00","swom_access_allowed":null,"email_address":null,"market":"0","dggocart":"0","propane":null,"opening_time_wed":"07:00","state":"AZ","type_id":"DG","icon":"default","message":null,"bho":null,"ship_city":null,"closing_time_tue":"21:00","dgpickup":"0","rank":null,"store_info_url":null,"fedex":"0","opening_time_sat":"07:00","closing_time_fri":"21:00","isp_email_address":null,"map_url":null,"ship_postal_code":null,"amerig
# ...
